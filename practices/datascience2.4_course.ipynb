# %%
import numpy as np
arr2d_data = np.array([[80,65],[47,27],[98,74]])
print(arr2d_data)
array_x = arr2d_data[:, 0]
array_y = arr2d_data[:, 1]
print(array_x)
print(array_y)
# Out:
# [[80 65]
#  [47 27]
#  [98 74]]
# [80 47 98]
# [65 27 74]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
 
arr2d_data = np.array([[-15,-5],[23,45],[-13,23],[-76,-67]])
array_x = arr2d_data[:, 0]
array_y = arr2d_data[:, 1]

print(arr2d_data)
print(array_x)
print(array_y)
plt.scatter(array_x,  array_y, s=30, c='blue', alpha=1)
# Out:
# [[-15  -5]
#  [ 23  45]
#  [-13  23]
#  [-76 -67]]
# [-15  23 -13 -76]
# [ -5  45  23 -67]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

arr2d_data = np.loadtxt(fname='2d.csv',delimiter=',')
array_x = arr2d_data[:, 0]
array_y = arr2d_data[:, 1]
plt.scatter(array_x,array_y,s=10,c='blue',alpha=0.5)

# %%
H = plt.hist2d(array_x,array_y,cmap='Blues')
plt.colorbar(H[3])

# %%
import seaborn as sns

sns.set(style='white')
sns.jointplot(array_x,array_y)

# %%
arr2d_cov = np.cov(array_x,array_y,bias=True)
arr2d_r= np.corrcoef(array_x,array_y)
print('共分散')
print(arr2d_cov)
print('相関係数')
print(arr2d_r)
# Out:
# 共分散
# [[9.562532   8.36594145]
#  [8.36594145 9.8016078 ]]
# 相関係数
# [[1.         0.86413125]
#  [0.86413125 1.        ]]
